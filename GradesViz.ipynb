# %% [markdown]
# <a href="https://colab.research.google.com/github/jaredguting/colab-projects/blob/main/GradesViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from google.colab import drive
drive.mount('/content/drive')
dir_name = '/content/drive/MyDrive/Colab Notebooks/Datasets/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importing Created Dataset

# %%
dataset = pd.read_csv(f"{dir_name}Guting_final_dataset.csv")
dataset
# Out:
#    class_code     subj_no                                          subj_desc  \
# 0     16-5031    ASF 1000                          Arrupe Social Formation 0
# 1       4-310     CS 1130                          Introduction to Computing
# 2       4-501    DSC 1131                             Computer Programming 1
# 3      16-461     GE 1105                             Understanding the Self
# 4      16-658     GE 1106                            Purposive Communication
# 5      16-519     GE 1108                    Mathematics in the Modern World
# 6    16-761-B     PE 1114                                         Path-Fit 1
# 7      16-670  Philo 1000                                         Philosophy
# 8     16-5040    ASF 1101                          Arrupe Social Formation 1
# 9     16-6121    ASF 1102  National Service Training Program - Civic Welf...
# 10      4-313     CS 1232                              Discrete Structures 1
# ...

# %% [markdown]
# This code will get the basic information about the imported dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   class_code  35 non-null     object
#  1   subj_no     35 non-null     object
#  2   subj_desc   35 non-null     object
#  3   units       35 non-null     int64
#  4   final       35 non-null     object
#  5   qpi         35 non-null     float64
#  6   year_sem    35 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.0+ KB

# %% [markdown]
# #**Grades Section**

# %% [markdown]
# ##Filtering the dataset based on semester

# %% [markdown]
# ###1st Year 1st Semester

# %% [markdown]
# Displaying the dataframe for the 1st year 1st semester

# %%
dataset_1st1st = dataset[(dataset['year_sem'] == '1styr_1stsem')]
dataset_1st1st
# Out:
#   class_code     subj_no                        subj_desc  units final   qpi  \
# 0    16-5031    ASF 1000        Arrupe Social Formation 0      2     A  3.28
# 1      4-310     CS 1130        Introduction to Computing      3     A  3.28
# 2      4-501    DSC 1131           Computer Programming 1      3     A  3.28
# 3     16-461     GE 1105           Understanding the Self      3     A  3.28
# 4     16-658     GE 1106          Purposive Communication      3     B  3.28
# 5     16-519     GE 1108  Mathematics in the Modern World      3    B+  3.28
# 6   16-761-B     PE 1114                       Path-Fit 1      2    B+  3.28
# 7     16-670  Philo 1000                       Philosophy      3     D  3.28
#
#        year_sem
# 0  1styr_1stsem
# 1  1styr_1stsem
# 2  1styr_1stsem
# 3  1styr_1stsem
# 4  1styr_1stsem
# 5  1styr_1stsem
# 6  1styr_1stsem
# 7  1styr_1stsem

# %% [markdown]
# Displaying the letter grade 'A' in the dataframe

# %%
dataset_1st1stA = dataset_1st1st[dataset_1st1st['final'] == 'A']
dataset_1st1stA
# Out:
#   class_code   subj_no                  subj_desc  units final   qpi  \
# 0    16-5031  ASF 1000  Arrupe Social Formation 0      2     A  3.28
# 1      4-310   CS 1130  Introduction to Computing      3     A  3.28
# 2      4-501  DSC 1131     Computer Programming 1      3     A  3.28
# 3     16-461   GE 1105     Understanding the Self      3     A  3.28
#
#        year_sem
# 0  1styr_1stsem
# 1  1styr_1stsem
# 2  1styr_1stsem
# 3  1styr_1stsem

# %% [markdown]
# Retrieving the value count of the letter grade 'A' in the filtered dataframe

# %%
dataset_1st1st[dataset_1st1st['final'] == 'A']['final'].value_counts()
# Out:
# A    4
# Name: final, dtype: int64

# %% [markdown]
# Displaying the non-'A' letter grade in the dataframe

# %%
dataset_1st1stnotA = dataset_1st1st[dataset_1st1st['final'] != 'A']
dataset_1st1stnotA
# Out:
#   class_code     subj_no                        subj_desc  units final   qpi  \
# 4     16-658     GE 1106          Purposive Communication      3     B  3.28
# 5     16-519     GE 1108  Mathematics in the Modern World      3    B+  3.28
# 6   16-761-B     PE 1114                       Path-Fit 1      2    B+  3.28
# 7     16-670  Philo 1000                       Philosophy      3     D  3.28
#
#        year_sem
# 4  1styr_1stsem
# 5  1styr_1stsem
# 6  1styr_1stsem
# 7  1styr_1stsem

# %% [markdown]
# Retrieving the value count of the non-'A' letter grade in the filtered dataframe

# %%
dataset_1st1st[dataset_1st1st['final'] != 'A']['final'].value_counts()
# Out:
# B+    2
# B     1
# D     1
# Name: final, dtype: int64

# %% [markdown]
# ###1st Year 2nd Semester

# %% [markdown]
# Displaying the dataframe for the 1st year 2nd semester

# %%
dataset_1st2nd = dataset[(dataset['year_sem'] == '1styr_2ndsem')]
dataset_1st2nd
# Out:
#    class_code    subj_no                                          subj_desc  \
# 8     16-5040   ASF 1101                          Arrupe Social Formation 1
# 9     16-6121   ASF 1102  National Service Training Program - Civic Welf...
# 10      4-313    CS 1232                              Discrete Structures 1
# 11      4-502   DSC 1233                             Computer Programming 2
# 12     16-632    GE 1210                     Readings in Philippine History
# 13     16-674    GE 1211                             The Contemporary World
# 14     16-686    GE 1212                    Science, Technology and Society
# 15      4-503  MATH 2171                              Differential Calculus
# 16     16-772    PE 1215                                         Path-Fit 2
#
#     units final   qpi      year_sem
# 8       2    C+  3.09  1styr_2ndsem
# 9       3     A  3.09  1styr_2ndsem
# 10      3     F  3.09  1styr_2ndsem
# 11      3     A  3.09  1styr_2ndsem
# ...

# %% [markdown]
# Retrieving the value count of the letter grade 'A' in the filtered dataframe

# %%
dataset_1st2nd[dataset_1st2nd['final'] == 'A']['final'].value_counts()
# Out:
# A    4
# Name: final, dtype: int64

# %% [markdown]
# Displaying the non-'A' letter grade in the dataframe

# %%
dataset_1st2ndnotA = dataset_1st2nd[dataset_1st2nd['final'] != 'A']
dataset_1st2ndnotA
# Out:
#    class_code   subj_no                       subj_desc  units final   qpi  \
# 8     16-5040  ASF 1101       Arrupe Social Formation 1      2    C+  3.09
# 10      4-313   CS 1232           Discrete Structures 1      3     F  3.09
# 12     16-632   GE 1210  Readings in Philippine History      3     B  3.09
# 13     16-674   GE 1211          The Contemporary World      3     B  3.09
# 16     16-772   PE 1215                      Path-Fit 2      2     B  3.09
#
#         year_sem
# 8   1styr_2ndsem
# 10  1styr_2ndsem
# 12  1styr_2ndsem
# 13  1styr_2ndsem
# 16  1styr_2ndsem

# %% [markdown]
# Retrieving the value count of the non-'A' letter grade in the filtered dataframe

# %%
dataset_1st2nd[dataset_1st2nd['final'] != 'A']['final'].value_counts()
# Out:
# B     3
# C+    1
# F     1
# Name: final, dtype: int64

# %% [markdown]
# ###Summer

# %% [markdown]
# Displaying the dataframe for the 1st year Summer

# %%
dataset_sum = dataset[(dataset['year_sem'] == 'summer')]
dataset_sum
# Out:
#    class_code  subj_no                    subj_desc  units final  qpi year_sem
# 17      4-102  IT 1335  Discrete Mathematics for IT      3     D  1.0   summer

# %% [markdown]
# Retrieving the value count of the letter grade 'A' in the filtered dataframe

# %%
dataset_sum[dataset_sum['final'] == 'A']['final'].value_counts()
# Out:
# Series([], Name: final, dtype: int64)

# %% [markdown]
# Displaying the non-'A' letter grade in the dataframe

# %%
dataset_sumnotA = dataset_sum[dataset_sum['final'] != 'A']
dataset_sumnotA
# Out:
#    class_code  subj_no                    subj_desc  units final  qpi year_sem
# 17      4-102  IT 1335  Discrete Mathematics for IT      3     D  1.0   summer

# %% [markdown]
# Retrieving the value count of the non-'A' letter grade in the filtered dataframe

# %%
dataset_sum[dataset_sum['final'] != 'A']['final'].value_counts()
# Out:
# D    1
# Name: final, dtype: int64

# %% [markdown]
# ###2nd Year 1st Semester

# %% [markdown]
# Displaying the dataframe for the 2nd year 1st semester

# %%
dataset_2nd1st = dataset[(dataset['year_sem'] == '2ndyr_1stsem')]
dataset_2nd1st
# Out:
#    class_code    subj_no                              subj_desc  units final  \
# 18      4-307    CS 2137                 Information Management      3    C+
# 19      4-503   DSC 2135            Object Oriented Programming      3     C
# 20     16-101    GE 1107                       Art Appreciation      3    B+
# 21     16-162    GE 1109                                 Ethics      3     C
# 22     16-617    GE 3118  Elective 1: Interdisciplinary Studies      3     A
# 23      4-317  MATH 2138                         Linear Algebra      3     A
# 24      4-504  MATH 2272                      Integral Calculus      5     D
# 25     16-674    PE 2116                Path-Fit 3: Team Sports      2     B
#
#     qpi      year_sem
# 18  2.6  2ndyr_1stsem
# 19  2.6  2ndyr_1stsem
# 20  2.6  2ndyr_1stsem
# 21  2.6  2ndyr_1stsem
# 22  2.6  2ndyr_1stsem
# 23  2.6  2ndyr_1stsem
# 24  2.6  2ndyr_1stsem
# 25  2.6  2ndyr_1stsem

# %% [markdown]
# Retrieving the value count of the letter grade 'A' in the filtered dataframe

# %%
dataset_2nd1st[dataset_2nd1st['final'] == 'A']['final'].value_counts()
# Out:
# A    2
# Name: final, dtype: int64

# %% [markdown]
# Displaying the non-'A' letter grade in the dataframe

# %%
dataset_2nd1stnotA = dataset_2nd1st[dataset_2nd1st['final'] != 'A']
dataset_2nd1stnotA
# Out:
#    class_code    subj_no                    subj_desc  units final  qpi  \
# 18      4-307    CS 2137       Information Management      3    C+  2.6
# 19      4-503   DSC 2135  Object Oriented Programming      3     C  2.6
# 20     16-101    GE 1107             Art Appreciation      3    B+  2.6
# 21     16-162    GE 1109                       Ethics      3     C  2.6
# 24      4-504  MATH 2272            Integral Calculus      5     D  2.6
# 25     16-674    PE 2116      Path-Fit 3: Team Sports      2     B  2.6
#
#         year_sem
# 18  2ndyr_1stsem
# 19  2ndyr_1stsem
# 20  2ndyr_1stsem
# 21  2ndyr_1stsem
# 24  2ndyr_1stsem
# 25  2ndyr_1stsem

# %% [markdown]
# Retrieving the value count of the non-'A' letter grade in the filtered dataframe

# %%
dataset_2nd1st[dataset_2nd1st['final'] != 'A']['final'].value_counts()
# Out:
# C     2
# C+    1
# B+    1
# D     1
# B     1
# Name: final, dtype: int64

# %% [markdown]
# ###2nd Year 2nd Semester

# %% [markdown]
# Displaying the dataframe for the 2nd year 2nd semester

# %%
dataset_2nd2nd = dataset[(dataset['year_sem'] == '2ndyr_2ndsem')]
dataset_2nd2nd
# Out:
#    class_code    subj_no                                          subj_desc  \
# 26    16-6041   ASF 1203  National Service Training Program - Civic Welf...
# 27      4-314    CS 2238                                  Basic Electronics
# 28      4-503   DSC 2236                                      Linear Models
# 29      4-504   DSC 2237                              Business Intelligence
# 30      4-505   DSC 2238                          Data Science Fundamentals
# 31      5-507   DSC 2239                     Data Structures and Algorithms
# 32     16-200    GE 1213                            Life and Works of Rizal
# 33      4-321  MATH 3274                          Probablity and Statistics
# 34     16-360    PE 2217             Path-Fit 4: Individual and Dual Sports
#
#     units final   qpi      year_sem
# 26      3     A  3.22  2ndyr_2ndsem
# 27      5     B  3.22  2ndyr_2ndsem
# 28      3    B+  3.22  2ndyr_2ndsem
# 29      3    B+  3.22  2ndyr_2ndsem
# ...

# %% [markdown]
# Retrieving the value count of the letter grade 'A' in the filtered dataframe

# %%
dataset_2nd2nd[dataset_2nd2nd['final'] == 'A']['final'].value_counts()
# Out:
# A    2
# Name: final, dtype: int64

# %% [markdown]
# Displaying the non-'A' letter grade in the dataframe

# %%
dataset_2nd2ndnotA = dataset_2nd2nd[dataset_2nd2nd['final'] != 'A']
dataset_2nd2ndnotA
# Out:
#    class_code   subj_no                               subj_desc  units final  \
# 27      4-314   CS 2238                       Basic Electronics      5     B
# 28      4-503  DSC 2236                           Linear Models      3    B+
# 29      4-504  DSC 2237                   Business Intelligence      3    B+
# 30      4-505  DSC 2238               Data Science Fundamentals      3    C+
# 31      5-507  DSC 2239          Data Structures and Algorithms      3     B
# 32     16-200   GE 1213                 Life and Works of Rizal      3     B
# 34     16-360   PE 2217  Path-Fit 4: Individual and Dual Sports      2    B+
#
#      qpi      year_sem
# 27  3.22  2ndyr_2ndsem
# 28  3.22  2ndyr_2ndsem
# 29  3.22  2ndyr_2ndsem
# 30  3.22  2ndyr_2ndsem
# 31  3.22  2ndyr_2ndsem
# 32  3.22  2ndyr_2ndsem
# 34  3.22  2ndyr_2ndsem

# %% [markdown]
# Retrieving the value count of the non-'A' letter grade in the filtered dataframe

# %%
dataset_2nd2nd[dataset_2nd2nd['final'] != 'A']['final'].value_counts()
# Out:
# B     3
# B+    3
# C+    1
# Name: final, dtype: int64

# %% [markdown]
# ##*Line Graph and Histograms*

# %% [markdown]
# ###Line plot representation for the whole dataset

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=dataset, x='year_sem', y='qpi')
# Out:
# <Axes: xlabel='year_sem', ylabel='qpi'>

# %% [markdown]
# ###1st year 1st semester histogram of letter grades

# %%
sns.histplot(data=dataset_1st1st, x = 'final')
# Out:
# <Axes: xlabel='final', ylabel='Count'>

# %% [markdown]
# ###1st year 2nd semester histogram of letter grades

# %%
sns.histplot(data=dataset_1st2nd, x = 'final')
# Out:
# <Axes: xlabel='final', ylabel='Count'>

# %% [markdown]
# ###summer histogram of letter grades

# %%
sns.histplot(data=dataset_sum, x = 'final')
# Out:
# <Axes: xlabel='final', ylabel='Count'>

# %% [markdown]
# ###2nd year 1st semester histogram of letter grades

# %%
sns.histplot(data=dataset_2nd1st, x = 'final')
# Out:
# <Axes: xlabel='final', ylabel='Count'>

# %% [markdown]
# ###2nd year 2nd semester histogram of letter grades

# %%
sns.histplot(data=dataset_2nd2nd, x = 'final')
# Out:
# <Axes: xlabel='final', ylabel='Count'>

# %% [markdown]
# ##*Pie Chart*

# %% [markdown]
# ###1st year 1st semester

# %%
grade_counts1st1st = dataset_1st1st['final'].value_counts()
grade_counts1st1st
# Out:
# A     4
# B+    2
# B     1
# D     1
# Name: final, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(grade_counts1st1st, labels=grade_counts1st1st.index, autopct='%1.1f%%')
plt.title('Percentage of Letter Grades')
plt.show()

# %% [markdown]
# ###1st year 2nd semester

# %%
grade_counts1st2nd = dataset_1st2nd['final'].value_counts()
grade_counts1st2nd
# Out:
# A     4
# B     3
# C+    1
# F     1
# Name: final, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(grade_counts1st2nd, labels=grade_counts1st2nd.index, autopct='%1.1f%%')
plt.title('Percentage of Letter Grades')
plt.show()

# %% [markdown]
# ###summer

# %%
grade_countssum = dataset_sum['final'].value_counts()
grade_countssum
# Out:
# D    1
# Name: final, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(grade_countssum, labels=grade_countssum.index, autopct='%1.1f%%')
plt.title('Percentage of Letter Grades')
plt.show()

# %% [markdown]
# ###2nd year 1st semester

# %%
grade_counts2nd1st = dataset_2nd1st['final'].value_counts()
grade_counts2nd2nd
# Out:
# B     3
# B+    3
# A     2
# C+    1
# Name: final, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(grade_counts2nd1st, labels=grade_counts2nd1st.index, autopct='%1.1f%%')
plt.title('Percentage of Letter Grades')
plt.show()

# %% [markdown]
# ###2nd year 2nd semester

# %%
grade_counts2nd2nd = dataset_2nd2nd['final'].value_counts()
grade_counts2nd2nd
# Out:
# B     3
# B+    3
# A     2
# C+    1
# Name: final, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(grade_counts2nd2nd, labels=grade_counts2nd2nd.index, autopct='%1.1f%%')
plt.title('Percentage of Letter Grades')
plt.show()

# %% [markdown]
# #**Subjects Section**

# %% [markdown]
# ###Minor Subjects

# %% [markdown]
# Retrieving subject rows that are GE, ASF, and PE

# %%
minor_subjects = dataset[dataset['subj_no'].str.startswith(('GE', 'PE', 'ASF'))]
minor_subjects
# Out:
#    class_code   subj_no                                          subj_desc  \
# 0     16-5031  ASF 1000                          Arrupe Social Formation 0
# 3      16-461   GE 1105                             Understanding the Self
# 4      16-658   GE 1106                            Purposive Communication
# 5      16-519   GE 1108                    Mathematics in the Modern World
# 6    16-761-B   PE 1114                                         Path-Fit 1
# 8     16-5040  ASF 1101                          Arrupe Social Formation 1
# 9     16-6121  ASF 1102  National Service Training Program - Civic Welf...
# 12     16-632   GE 1210                     Readings in Philippine History
# 13     16-674   GE 1211                             The Contemporary World
# 14     16-686   GE 1212                    Science, Technology and Society
# 16     16-772   PE 1215                                         Path-Fit 2
# ...

# %% [markdown]
# Retrieving the value count of GE subjects - True Values are the GE values

# %%
minor_subjects['subj_no'].str.startswith('GE').value_counts()
# Out:
# True     10
# False     8
# Name: subj_no, dtype: int64

# %% [markdown]
# ###Major Subjects

# %% [markdown]
# Retrieving subject rows that are DSC, CS, and Math

# %%
major_subjects = dataset[dataset['subj_no'].str.startswith(('DSC', 'CS', 'MATH'))]
major_subjects
# Out:
#    class_code    subj_no                       subj_desc  units final   qpi  \
# 1       4-310    CS 1130       Introduction to Computing      3     A  3.28
# 2       4-501   DSC 1131          Computer Programming 1      3     A  3.28
# 10      4-313    CS 1232           Discrete Structures 1      3     F  3.09
# 11      4-502   DSC 1233          Computer Programming 2      3     A  3.09
# 15      4-503  MATH 2171           Differential Calculus      5     A  3.09
# 18      4-307    CS 2137          Information Management      3    C+  2.60
# 19      4-503   DSC 2135     Object Oriented Programming      3     C  2.60
# 23      4-317  MATH 2138                  Linear Algebra      3     A  2.60
# 24      4-504  MATH 2272               Integral Calculus      5     D  2.60
# 27      4-314    CS 2238               Basic Electronics      5     B  3.22
# 28      4-503   DSC 2236                   Linear Models      3    B+  3.22
# ...

# %% [markdown]
# Retrieving the value count of DSC subjects - True Values are the DSC values

# %%
major_subjects['subj_no'].str.startswith('DSC').value_counts()
# Out:
# False    8
# True     7
# Name: subj_no, dtype: int64

# %% [markdown]
# #**Bonus**

# %% [markdown]
# Retrieving the value count of each subject by splitting subj_no

# %%
subject_prefixes = ['GE', 'PE', 'ASF', 'DSC', 'CS', 'MATH']
prefixes = dataset['subj_no'].str.split().str[0]
subject_counts = prefixes[prefixes.isin(subject_prefixes)].value_counts()

# %% [markdown]
# Pie chart displaying the percentages of all GE, PE, ASF, DSC, CS and Math subjects

# %%
plt.figure(figsize=(10, 8))
plt.pie(subject_counts, labels=subject_counts.index, autopct='%1.1f%%')
plt.title('Percentage of GE, PE, ASF, DSC, CS, and Math Subjects')
plt.show()

# %% [markdown]
# *2nd bonus question is the same with what's given for instruction 2g.*
